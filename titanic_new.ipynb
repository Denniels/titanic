# %% [markdown]
# # 🚢 La Historia del Titanic a través de los Datos
#
# ¡Bienvenido a nuestro viaje de análisis de datos del Titanic! En este notebook, exploraremos la fascinante historia del legendario RMS Titanic a través de los datos de sus pasajeros.
#
# > *"Los números cuentan historias, y la historia del Titanic es una de las más memorables."*
#
# ## 🎯 ¿Qué Descubriremos?
#
# 1. ¿Quiénes tenían más probabilidades de sobrevivir?
# 2. ¿Importaba la clase social?
# 3. ¿Las familias permanecieron juntas?
# 4. ¿El precio del boleto marcó la diferencia?

# %% [markdown]
# # 🚢 Análisis del Dataset del Titanic
#
# Este notebook presenta un análisis exploratorio del dataset del Titanic, uno de los conjuntos de datos más populares en ciencia de datos.
#
# ## Objetivos
#
# 1. 📊 Realizar un análisis exploratorio completo
# 2. 🔍 Identificar patrones de supervivencia
# 3. 📈 Visualizar relaciones entre variables
# 4. 🤖 Preparar los datos para modelado

# %%
# Configuración inicial
import sys
from pathlib import Path

# Agregar directorio src al path
src_path = Path.cwd() / 'src'
if str(src_path) not in sys.path:
    sys.path.append(str(src_path))

# Importar módulos propios
from utils import configurar_visualizacion
from data_loader import cargar_datos, preparar_datos
from eda import (
    plot_supervivencia_general,
    plot_supervivencia_por_clase,
    plot_piramide_edad_genero,
    plot_familias,
    plot_tarifas_supervivencia
)

# Configurar visualizaciones
configurar_visualizacion()

# %% [markdown]
# # 🚢 Análisis del Dataset del Titanic
#
# Este notebook presenta un análisis exploratorio detallado del famoso dataset del Titanic, uno de los conjuntos de datos más populares en el campo del análisis de datos y machine learning.
#
# ## Objetivos del Análisis
#
# 1. 📊 Realizar un análisis exploratorio completo de los datos
# 2. 🔍 Identificar patrones y tendencias en la supervivencia de pasajeros
# 3. 📈 Visualizar relaciones entre diferentes variables
# 4. 🧮 Preparar los datos para modelado predictivo
#
# ## Estructura del Análisis
#
# 1. Configuración del Entorno
# 2. Carga y Preparación de Datos
# 3. Análisis Exploratorio de Datos (EDA)
# 4. Visualizaciones Detalladas
# 5. Conclusiones
#
# ## Dataset
#
# El dataset del Titanic contiene información sobre los pasajeros que viajaban a bordo del RMS Titanic cuando se hundió el 15 de abril de 1912. Incluye datos como:
#
# - Clase de pasajero
# - Edad
# - Género
# - Tarifa pagada
# - Puerto de embarque
# - Si sobrevivieron o no al desastre

# %%
# Importación de librerías necesarias
import sys
from pathlib import Path

# Agregar el directorio src al path de Python
src_path = Path.cwd() / 'src'
if str(src_path) not in sys.path:
    sys.path.append(str(src_path))

# Importar módulos propios
from utils import configurar_visualizacion, mostrar_estado_dependencias
from data_loader import cargar_datos, preparar_datos
from eda import (
    plot_supervivencia_general,
    plot_supervivencia_por_clase,
    plot_piramide_edad_genero,
    plot_familias,
    plot_tarifas_supervivencia
)

# Configurar el entorno de visualización
configurar_visualizacion()

# Mostrar información sobre las dependencias instaladas
mostrar_estado_dependencias()
# Out:
# ✅ Todas las dependencias están instaladas y actualizadas!

# %% [markdown]
# # 🚢 Análisis del Dataset del Titanic
#
# Este notebook realiza un análisis exploratorio detallado del dataset del Titanic.

# %%
# Importar funciones necesarias
from src.data_loader import cargar_datos, preparar_datos
from src.eda import (
    plot_supervivencia_general,
    plot_supervivencia_por_clase,
    plot_piramide_edad_genero,
    plot_familias,
    plot_tarifas_supervivencia
)

# Configurar visualizaciones
# %matplotlib inline

# %% [markdown]
# ## 📚 Carga y Preparación de Datos

# %%
# Cargar y preparar datos
df = cargar_datos('train')
df = preparar_datos(df)

print("📊 Dimensiones del dataset:", df.shape)
print("\nPrimeras filas del dataset:")
df.head()
# Out:
# 📊 Dimensiones del dataset: (891, 15)
#
# Primeras filas del dataset:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize  IsAlone Title
# 0      0         A/5 21171   7.2500   NaN        S           2        0    Mr
# 1      0          PC 17599  71.2833   C85        C           2        0   Mrs
# ...

# %% [markdown]
# ## 🔍 Análisis de Supervivencia

# %%
# Supervivencia general
plot_supervivencia_general(df)
# Out:
# e:\repos\titanic\src\eda.py:43: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=['No Sobrevivió', 'Sobrevivió'],

# %% [markdown]
# ### Análisis por Clase Social

# %%
# Supervivencia por clase
plot_supervivencia_por_clase(df)
# Out:
# e:\repos\titanic\src\eda.py:68: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=df, x='Pclass', y='Survived',

# %% [markdown]
# ### Análisis Demográfico

# %%
# Distribución demográfica
plot_piramide_edad_genero(df)

# %% [markdown]
# ### Análisis de Grupos Familiares

# %%
# Análisis familiar
plot_familias(df)
# Out:
# e:\repos\titanic\src\eda.py:135: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='FamilySize', y='Survived', ax=ax1,
# e:\repos\titanic\src\eda.py:149: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Pclass', y='FamilySize', ax=ax2,
# e:\repos\titanic\src\eda.py:154: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Primera', 'Segunda', 'Tercera'])

# %% [markdown]
# ### Análisis de Tarifas

# %%
# Análisis de tarifas
plot_tarifas_supervivencia(df)
# Out:
# e:\repos\titanic\src\eda.py:166: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Survived', y='Fare', ax=ax1,
# e:\repos\titanic\src\eda.py:171: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(['Fallecidos', 'Sobrevivientes'])
# e:\repos\titanic\src\eda.py:174: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Pclass', y='Fare', ax=ax2,
# e:\repos\titanic\src\eda.py:179: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Primera', 'Segunda', 'Tercera'])

# %% [markdown]
# # 🚢 Análisis del Dataset del Titanic
#
# Este notebook realiza un análisis exploratorio detallado del dataset del Titanic.

# %% [markdown]
# ## ⚙️ Configuración Inicial
#
# Importamos las librerías y funciones necesarias para nuestro análisis:

# %%
# Importar funciones necesarias
from src.data_loader import cargar_datos, preparar_datos
from src.eda import (
    plot_supervivencia_general,
    plot_supervivencia_por_clase,
    plot_piramide_edad_genero,
    plot_familias,
    plot_tarifas_supervivencia
)

# Configurar visualizaciones
# %matplotlib inline

# %% [markdown]
# ## 📚 Carga y Preparación de Datos
#
# Cargamos el dataset de entrenamiento y realizamos la preparación inicial de los datos:

# %%
# Cargar y preparar datos
df = cargar_datos('train')
df = preparar_datos(df)

print("📊 Dimensiones del dataset:", df.shape)
print("\n📄 Primeras filas del dataset:")
df.head()
# Out:
# 📊 Dimensiones del dataset: (891, 15)
#
# 📄 Primeras filas del dataset:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize  IsAlone Title
# 0      0         A/5 21171   7.2500   NaN        S           2        0    Mr
# 1      0          PC 17599  71.2833   C85        C           2        0   Mrs
# ...

# %% [markdown]
# ## 🔍 Análisis Exploratorio
#
# Analizaremos los patrones de supervivencia desde diferentes perspectivas:

# %% [markdown]
# ### Supervivencia General
#
# Primero, veamos la distribución general de supervivencia:

# %%
# Visualizar supervivencia general
plot_supervivencia_general(df)
# Out:
# e:\repos\titanic\src\eda.py:43: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=['No Sobrevivió', 'Sobrevivió'],

# %% [markdown]
# ### Análisis por Clase Social
#
# La clase social fue un factor determinante en la supervivencia:

# %%
# Visualizar supervivencia por clase
plot_supervivencia_por_clase(df)
# Out:
# e:\repos\titanic\src\eda.py:68: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=df, x='Pclass', y='Survived',

# %% [markdown]
# ### Factores Demográficos
#
# La edad y el género jugaron un papel crucial:

# %%
# Visualizar pirámide demográfica
plot_piramide_edad_genero(df)

# %% [markdown]
# ### Impacto del Tamaño Familiar
#
# Analizaremos cómo el viajar en familia afectó la supervivencia:

# %%
# Visualizar factores familiares
plot_familias(df)
# Out:
# e:\repos\titanic\src\eda.py:135: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='FamilySize', y='Survived', ax=ax1,
# e:\repos\titanic\src\eda.py:149: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Pclass', y='FamilySize', ax=ax2,
# e:\repos\titanic\src\eda.py:154: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Primera', 'Segunda', 'Tercera'])

# %% [markdown]
# ### Análisis de Tarifas
#
# Por último, exploramos la relación entre el precio del billete y la supervivencia:

# %%
# Visualizar análisis de tarifas
plot_tarifas_supervivencia(df)
# Out:
# e:\repos\titanic\src\eda.py:166: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Survived', y='Fare', ax=ax1,
# e:\repos\titanic\src\eda.py:171: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(['Fallecidos', 'Sobrevivientes'])
# e:\repos\titanic\src\eda.py:174: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Pclass', y='Fare', ax=ax2,
# e:\repos\titanic\src\eda.py:179: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Primera', 'Segunda', 'Tercera'])

# %% [markdown]
# ## 📊 Carga y Preparación de Datos
#
# Comenzaremos cargando los datos del Titanic y realizando una preparación inicial para nuestro análisis.

# %%
# Importar funciones necesarias
from src.data_loader import cargar_datos, preparar_datos
from src.eda import (
    plot_supervivencia_general,
    plot_supervivencia_por_clase,
    plot_piramide_edad_genero,
    plot_familias,
    plot_tarifas_supervivencia
)

# Cargar y preparar datos
df = cargar_datos('train')
df = preparar_datos(df)

print("📊 Dimensiones del dataset:", df.shape)
print("\n📄 Primeras filas del dataset:")
df.head()
# Out:
# 📊 Dimensiones del dataset: (891, 15)
#
# 📄 Primeras filas del dataset:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize  IsAlone Title
# 0      0         A/5 21171   7.2500   NaN        S           2        0    Mr
# 1      0          PC 17599  71.2833   C85        C           2        0   Mrs
# ...

# %% [markdown]
# ## 🔎 Análisis Exploratorio
#
# Realizaremos un análisis detallado de los patrones de supervivencia en el Titanic.

# %%
# Visualizar supervivencia general
plot_supervivencia_general(df)
# Out:
# e:\repos\titanic\src\eda.py:43: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=['No Sobrevivió', 'Sobrevivió'],

# %% [markdown]
# ### Análisis por Clase Social

# %%
# Visualizar supervivencia por clase
plot_supervivencia_por_clase(df)
# Out:
# e:\repos\titanic\src\eda.py:68: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=df, x='Pclass', y='Survived',

# %% [markdown]
# ### Análisis Demográfico

# %%
# Visualizar pirámide demográfica
plot_piramide_edad_genero(df)

# %% [markdown]
# ### Análisis de Factores Familiares

# %%
# Visualizar factores familiares
plot_familias(df)
# Out:
# e:\repos\titanic\src\eda.py:135: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='FamilySize', y='Survived', ax=ax1,
# e:\repos\titanic\src\eda.py:149: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Pclass', y='FamilySize', ax=ax2,
# e:\repos\titanic\src\eda.py:154: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Primera', 'Segunda', 'Tercera'])

# %% [markdown]
# ### Análisis de Tarifas

# %%
# Visualizar análisis de tarifas
plot_tarifas_supervivencia(df)
# Out:
# e:\repos\titanic\src\eda.py:166: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Survived', y='Fare', ax=ax1,
# e:\repos\titanic\src\eda.py:171: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(['Fallecidos', 'Sobrevivientes'])
# e:\repos\titanic\src\eda.py:174: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Pclass', y='Fare', ax=ax2,
# e:\repos\titanic\src\eda.py:179: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Primera', 'Segunda', 'Tercera'])

# %% [markdown]
# # 🚢 Análisis del Dataset del Titanic
#
# Este notebook realiza un análisis exploratorio detallado de los datos del Titanic para entender los factores que influyeron en la supervivencia de los pasajeros.
#
# ## 🎯 Objetivos
#
# 1. Analizar las características demográficas de los pasajeros
# 2. Identificar patrones de supervivencia
# 3. Visualizar relaciones entre variables
# 4. Extraer conclusiones relevantes

# %%
# Configuración inicial
from src.utils import configurar_visualizacion, mostrar_estado_dependencias

# Verificar y configurar el entorno
mostrar_estado_dependencias()
configurar_visualizacion()

print('✅ Entorno configurado correctamente!')
# Out:
# ✅ Todas las dependencias están instaladas y actualizadas!
# ✅ Entorno configurado correctamente!

# %% [markdown]
# ## 📜 Contexto Histórico
#
# El RMS Titanic fue un transatlántico británico que se hundió en las aguas del Atlántico Norte en la noche del 14 al 15 de abril de 1912, durante su viaje inaugural desde Southampton a Nueva York.
#
# ### Datos Importantes:
# - **Fecha del hundimiento**: 15 de abril de 1912
# - **Ubicación**: Océano Atlántico Norte
# - **Pasajeros totales**: 2,224
# - **Fallecidos**: ~1,500
# - **Sobrevivientes**: ~722
#
# ### Clases Sociales a Bordo:
# 1. **Primera Clase**: Lujo y comodidades excepcionales
# 2. **Segunda Clase**: Comparable a primera clase en otros barcos
# 3. **Tercera Clase**: Clase turista

# %% [markdown]
# ## 📊 Estructura de los Datos
#
# ### Variables del Dataset:
#
# - **survived**: Supervivencia (0 = No, 1 = Sí)
# - **pclass**: Clase del pasajero (1, 2, 3)
# - **name**: Nombre completo
# - **sex**: Género
# - **age**: Edad en años
# - **sibsp**: Número de hermanos/cónyuges a bordo
# - **parch**: Número de padres/hijos a bordo
# - **ticket**: Número de billete
# - **fare**: Tarifa pagada
# - **cabin**: Número de cabina
# - **embarked**: Puerto de embarque (C = Cherbourg, Q = Queenstown, S = Southampton)

# %%
# Importar funciones necesarias
from src.data_loader import cargar_datos, preparar_datos
from src.eda import (
    analizar_valores_faltantes,
    plot_supervivencia_por_variable,
    analisis_demografico,
    plot_distribucion_edad,
    plot_correlaciones
)

# Cargar y preparar datos
df = cargar_datos('train')
df = preparar_datos(df)

print(f"Dimensiones del dataset: {df.shape}")
print("\nPrimeras filas del dataset:")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[67], line 3
#       1 # Importar funciones necesarias
#       2 from src.data_loader import cargar_datos, preparar_datos
# ----> 3 from src.eda import (
#       4     analizar_valores_faltantes,
#       5     plot_supervivencia_por_variable,
#       6     analisis_demografico,
#       7     plot_distribucion_edad,
#       8     plot_correlaciones
#       9 )
#      11 # Cargar y preparar datos
#      12 df = cargar_datos('train')
#
# ImportError: cannot import name 'plot_supervivencia_por_variable' from 'src.eda' (e:\repos\titanic\src\eda.py)

# %% [markdown]
# ## 🔍 Análisis Exploratorio
#
# ### Análisis de Valores Faltantes

# %%
# Analizar valores faltantes
resumen_faltantes = analizar_valores_faltantes(df)
display(resumen_faltantes)

# Obtener estadísticas demográficas
stats = analisis_demografico(df)

# Visualizaciones
plot_distribucion_edad(df)
plot_supervivencia_por_variable(df, 'Pclass', 'Tasa de Supervivencia por Clase')
plot_supervivencia_por_variable(df, 'Sex', 'Tasa de Supervivencia por Género')
plot_correlaciones(df)
# Out:
#        Valores Faltantes  Porcentaje
# Cabin                687   77.104377
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 6
#       3 display(resumen_faltantes)
#       5 # Obtener estadísticas demográficas
# ----> 6 stats = analisis_demografico(df)
#       8 # Visualizaciones
#       9 plot_distribucion_edad(df)
#
# NameError: name 'analisis_demografico' is not defined

# %% [markdown]
# ## 📈 Análisis Visual de la Supervivencia
#
# Vamos a explorar visualmente los patrones de supervivencia en el Titanic desde diferentes perspectivas.

# %%
# Importar funciones necesarias
from src.data_loader import cargar_datos, preparar_datos
from src.eda import (
    plot_supervivencia_general,
    plot_supervivencia_por_clase,
    plot_piramide_edad_genero,
    plot_familias,
    plot_tarifas_supervivencia
)

# Cargar y preparar datos
df = cargar_datos('train')
df = preparar_datos(df)

print("\n📊 Dimensiones del dataset:", df.shape)
print("\n📄 Primeras filas del dataset:")
df.head()

# %% [markdown]
# ### 🔝 Análisis de Supervivencia General
#
# Comencemos analizando la distribución general de supervivencia en el desastre del Titanic:

# %%
# Visualizar supervivencia general
plot_supervivencia_general(df)

# %% [markdown]
# ### 📋 Análisis por Clase Social
#
# La clase social fue un factor determinante en la supervivencia. Veamos cómo se distribuyen las tasas de supervivencia entre las diferentes clases:

# %%
# Visualizar supervivencia por clase
plot_supervivencia_por_clase(df)

# %% [markdown]
# ### 👨‍👩‍👧 Análisis Demográfico
#
# La edad y el género jugaron un papel crucial en la supervivencia. La siguiente visualización nos muestra esta relación:

# %%
# Visualizar pirámide de edad y género
plot_piramide_edad_genero(df)

# %% [markdown]
# ### 👪 Análisis de Factores Familiares
#
# El tamaño de la familia y viajar acompañado afectó las probabilidades de supervivencia:

# %%
# Visualizar análisis familiar
plot_familias(df)

# %% [markdown]
# ### 💰 Análisis de Tarifas
#
# Por último, analizaremos cómo el precio del billete se relaciona con la supervivencia:

# %%
# Visualizar análisis de tarifas
plot_tarifas_supervivencia(df)

# %% [markdown]
# ## 📈 Análisis Visual de la Supervivencia
#
# Analizaremos los patrones de supervivencia desde diferentes perspectivas para entender qué factores fueron más determinantes.

# %%
import matplotlib.pyplot as plt
# Configurar visualización
from src.eda import (
    plot_supervivencia_general,
    plot_supervivencia_por_clase,
    plot_piramide_edad_genero,
    plot_familias,
    plot_tarifas_supervivencia
)

# Visualizar supervivencia general
plot_supervivencia_general(df)

# Añadir espacio entre gráficos
plt.show()

# Visualizar supervivencia por clase
plot_supervivencia_por_clase(df)
plt.show()

# Visualizar pirámide demográfica
plot_piramide_edad_genero(df)
plt.show()

# Visualizar análisis familiar
plot_familias(df)
plt.show()

# Visualizar análisis de tarifas
plot_tarifas_supervivencia(df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 from src.eda import (
#       2     plot_supervivencia_general,
#       3     plot_supervivencia_por_clase,
#       4     plot_piramide_edad_genero,
#       5     plot_familias,
#       6     plot_tarifas_supervivencia
#       7 )
#       9 # Visualizar supervivencia general
#      10 plot_supervivencia_general(df)
#
# ImportError: cannot import name 'plot_supervivencia_general' from 'src.eda' (e:\repos\titanic\src\eda.py)

# %% [markdown]
# ### 🔝 Supervivencia General
#
# El primer gráfico muestra la distribución general de supervivencia en el Titanic:
#
# - Aproximadamente el 38% de los pasajeros sobrevivieron
# - La mayoría (62%) no sobrevivieron al desastre
# - Estos números reflejan la magnitud de la tragédia y la insuficiencia de medidas de seguridad
#
# ### 📋 Supervivencia por Clase Social
#
# El segundo gráfico revela una clara correlación entre la clase social y la supervivencia:
#
# - **Primera Clase**: ~63% de supervivencia
#   - Mejor ubicación en el barco
#   - Más cerca de los botes salvavidas
#   - Mejor acceso a la información
#
# - **Segunda Clase**: ~47% de supervivencia
#   - Condiciones intermedias
#   - Acceso moderado a botes salvavidas
#
# - **Tercera Clase**: ~24% de supervivencia
#   - Ubicación en zonas bajas del barco
#   - Acceso limitado a botes salvavidas
#   - Posible desinformación durante la emergencia
#
# ### 👨‍👩‍👧 Distribucíon Demográfica
#
# La pirámide poblacional revela patrones importantes:
#
# **Por Género:**
# - Mujeres tuvieron mayor probabilidad de supervivencia
# - Hombres adultos tuvieron la menor tasa de supervivencia
# - Se evidencia la política de "mujeres y niños primero"
#
# **Por Edad:**
# - Niños de ambos géneros tuvieron mejores tasas de supervivencia
# - Adultos jóvenes masculinos fueron el grupo más afectado
# - Adultos mayores tuvieron menor tasa de supervivencia
#
# ### 👪 Factores Familiares
#
# El tamaño de la familia impactó significativamente en la supervivencia:
#
# - Personas solas: Menor tasa de supervivencia
# - Familias pequeñas (2-4): Mejor tasa de supervivencia
# - Familias grandes: Tasas decrecientes
#
# **Patrones por Clase:**
# - Primera clase: Grupos familiares pequeños
# - Segunda clase: Tamaños familiares moderados
# - Tercera clase: Familias más numerosas
#
# ### 💰 Análisis de Tarifas
#
# Las tarifas pagadas muestran una clara relación con la supervivencia:
#
# **Observaciones Principales:**
# - Correlación positiva entre tarifa y supervivencia
# - Primera clase: Tarifas muy superiores y mayor supervivencia
# - Tercera clase: Tarifas bajas y menor supervivencia
#
# **Implicaciones:**
# - El poder adquisitivo influyó en las probabilidades de supervivencia
# - Refleja las desigualdades sociales de la época
# - Las tarifas más altas implicaban mejor ubicación y acceso a botes salvavidas

# %% [markdown]
# # 🚢 Análisis del Dataset del Titanic
#
# Este notebook realiza un análisis exploratorio de los datos del Titanic para entender los factores que influyeron en la supervivencia de los pasajeros.

# %%
# Configuración inicial
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Configuración de visualizaciones
sns.set_theme(style='darkgrid')  # Usar tema de seaborn
sns.set_palette('husl')  # Configurar paleta de colores

# Configuración de pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Verificar la configuración con un gráfico de prueba
plt.figure(figsize=(6, 4))
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.title('Gráfico de Prueba')
plt.xlabel('X')
plt.ylabel('sin(x)')
plt.show()

print('✅ Configuración de visualizaciones completada exitosamente!')
# Out:
# ✅ Configuración de visualizaciones completada exitosamente!

# %% [markdown]
# ## 🎯 Objetivos
#
# 1. Analizar las características demográficas de los pasajeros
# 2. Identificar patrones de supervivencia
# 3. Visualizar relaciones entre variables
# 4. Generar conclusiones basadas en datos

# %% [markdown]
# ## 📊 Descripción del Dataset
#
# El dataset contiene información sobre los pasajeros del Titanic, incluyendo:
#
# - Características demográficas (edad, género)
# - Clase del pasaje
# - Información familiar
# - Puerto de embarque
# - Tarifa pagada
# - Si sobrevivieron o no al desastre

# %%
# Importar funciones personalizadas
from src.data_loader import cargar_datos, preparar_datos
from src.eda import analizar_valores_faltantes

# Cargar y preparar datos
df = cargar_datos('train')
print(f"Dimensiones del dataset: {df.shape}")

# Mostrar las primeras filas
df.head()
# Out:
# Dimensiones del dataset: (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# # 🚢 Análisis del Dataset del Titanic
#
# En este notebook realizaremos un análisis exploratorio detallado de los datos del Titanic, investigando los factores que influyeron en la supervivencia de los pasajeros.

# %%
# Configuración inicial
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Configuración de estilo para visualizaciones
sns.set_theme(style='darkgrid')  # Usar tema de seaborn directamente
sns.set_palette('husl')  # Configurar paleta de colores

# Configuración de pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Verificar la configuración con un gráfico de prueba
plt.figure(figsize=(6, 4))
plt.plot([1, 2, 3], [1, 4, 2], 'o-')
plt.title('Gráfico de prueba')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

print('✅ Configuración de visualizaciones completada exitosamente!')
# Out:
# ✅ Configuración de visualizaciones completada exitosamente!

# %% [markdown]
# ## 🎯 Objetivos del Análisis
#
# 1. Analizar patrones de supervivencia
# 2. Identificar factores determinantes
# 3. Crear visualizaciones informativas
# 4. Extraer conclusiones relevantes

# %% [markdown]
# # 🚢 Análisis del Dataset del Titanic
#
# En este notebook realizaremos un análisis exploratorio detallado de los datos del Titanic, investigando los factores que influyeron en la supervivencia de los pasajeros.
#
# ## 🎯 Objetivos
#
# 1. Analizar patrones de supervivencia
# 2. Identificar factores determinantes en la supervivencia
# 3. Visualizar relaciones entre variables
# 4. Generar insights sobre el desastre

# %%
# %matplotlib inline

# Importar módulos necesarios
from src.utils import mostrar_estado_dependencias, configurar_visualizacion

# Verificar dependencias
mostrar_estado_dependencias()

# Configurar visualizaciones
configurar_visualizacion()

print("✅ Entorno configurado correctamente!")
# Out:
# ✅ Todas las dependencias están instaladas y actualizadas!
# ✅ Entorno configurado correctamente!

# %% [markdown]
# ## 📊 Dataset del Titanic
#
# El dataset del Titanic contiene información sobre los pasajeros, incluyendo datos demográficos y si sobrevivieron o no al desastre. Los datos están divididos en:
#
# - **train.csv**: Conjunto de entrenamiento con 891 pasajeros
# - **test.csv**: Conjunto de prueba con 418 pasajeros
# - **gender_submission.csv**: Ejemplo de formato de submisión
#
# Vamos a comenzar cargando y explorando los datos de entrenamiento.

# %% [markdown]
# # 🚢 Análisis del Dataset del Titanic
#
# En este notebook realizaremos un análisis exploratorio detallado de los datos del Titanic, investigando los factores que influyeron en la supervivencia de los pasajeros.
#
# ## 🎯 Objetivos
#
# 1. Analizar patrones de supervivencia
# 2. Identificar factores determinantes en la supervivencia
# 3. Visualizar relaciones entre variables
# 4. Generar insights sobre el desastre
#
# ## 🛠️ Configuración del Entorno
#
# Primero verificaremos que el entorno tenga todas las dependencias necesarias.

# %%
# Importar módulo de utilidades
from src.utils import mostrar_estado_dependencias, configurar_visualizacion

# Verificar dependencias
mostrar_estado_dependencias()

# Configurar entorno de visualización
configurar_visualizacion()
# Out:
# ✅ Todas las dependencias están instaladas y actualizadas!

# %% [markdown]
# ## 📁 Estructura del Proyecto
#
# Este análisis está organizado en módulos para mantener el código limpio y modular:
#
# - `src/utils.py`: Utilidades y configuración
# - `src/data_loader.py`: Carga y preparación de datos
# - `src/eda.py`: Funciones de análisis exploratorio
# - `src/feature_engineering.py`: Ingeniería de características
# - `src/preprocessor.py`: Preprocesamiento de datos
# - `src/modeling.py`: Modelado y evaluación
#
# Los datos se encuentran en la carpeta `datasets/`:
# - `train.csv`: Conjunto de entrenamiento
# - `test.csv`: Conjunto de prueba
# - `gender_submission.csv`: Archivo de ejemplo de submisión

# %% [markdown]
# ## 📝 Análisis Exploratorio de Datos
#
# Comenzaremos cargando y preparando los datos para su análisis.

# %%
from src.data_loader import cargar_datos, preparar_datos
from src.eda import (
    analizar_valores_faltantes,
    plot_supervivencia_por_variable,
    analisis_demografico,
    plot_distribucion_edad,
    plot_correlaciones
)

# Cargar y preparar datos
df = cargar_datos('train')
df = preparar_datos(df)

# Mostrar dimensiones del dataset
print(f"Dimensiones del dataset: {df.shape}")

# Mostrar las primeras filas
df.head()
# Out:
# Dimensiones del dataset: (891, 15)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize  IsAlone Title
# 0      0         A/5 21171   7.2500   NaN        S           2        0    Mr
# 1      0          PC 17599  71.2833   C85        C           2        0   Mrs
# ...

# %% [markdown]
# ### Análisis de Valores Faltantes
#
# Verifiquemos si existen valores faltantes en nuestro dataset y cómo están distribuidos.

# %%
# Analizar valores faltantes
resumen_faltantes = analizar_valores_faltantes(df)
display(resumen_faltantes)
# Out:
#        Valores Faltantes  Porcentaje
# Cabin                687   77.104377

# %% [markdown]
# ### Análisis Demográfico
#
# Analizaremos las características demográficas principales de los pasajeros del Titanic.

# %%
# Obtener estadísticas demográficas
stats = analisis_demografico(df)

# Mostrar resultados de forma legible
print(f"Total de pasajeros: {stats['total_pasajeros']}")
print(f"Total de supervivientes: {stats['total_supervivientes']}")
print(f"Tasa de supervivencia: {stats['tasa_supervivencia']:.2f}%")
print(f"\nEdad promedio: {stats['edad_promedio']:.2f} años")
print(f"Precio promedio del billete: ${stats['precio_promedio']:.2f}")

print("\nDistribución por clase:")
for clase, cantidad in stats['distribucion_clases'].items():
    print(f"  - Clase {clase}: {cantidad} pasajeros")

print("\nDistribución por género:")
for genero, cantidad in stats['distribucion_genero'].items():
    print(f"  - {genero.capitalize()}: {cantidad} pasajeros")

# Visualizar distribuciones
plot_distribucion_edad(df)
plot_supervivencia_por_variable(df, 'Pclass', 'Tasa de Supervivencia por Clase')
plot_supervivencia_por_variable(df, 'Sex', 'Tasa de Supervivencia por Género')
plot_correlaciones(df)
# Out:
# Total de pasajeros: 891
# Total de supervivientes: 342
# Tasa de supervivencia: 38.38%
#
# Edad promedio: 29.36 años
# Precio promedio del billete: $32.20
#
# Distribución por clase:
#   - Clase 3: 491 pasajeros
#   - Clase 1: 216 pasajeros
#   - Clase 2: 184 pasajeros
#
# Distribución por género:
#   - Male: 577 pasajeros
#   - Female: 314 pasajeros

# %% [markdown]
# # 🚢 Análisis del Dataset del Titanic
#
# Este notebook realiza un análisis exploratorio detallado de los datos del Titanic, investigando los factores que influyeron en la supervivencia de los pasajeros.

# %%
# Importar librerías necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Markdown

# Configuración de visualizaciones
plt.style.use('seaborn-v0_8')
sns.set_palette('husl')
# %matplotlib inline

# Configurar opciones de pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
# Función para verificar dependencias
def verificar_dependencias():
    import pkg_resources
    import subprocess
    
    dependencias_requeridas = {
        'pandas': '1.3.0',
        'numpy': '1.20.0',
        'matplotlib': '3.4.0',
        'seaborn': '0.11.0',
        'scikit-learn': '0.24.0'
    }
    
    faltantes = []
    desactualizadas = []
    
    for paquete, version_min in dependencias_requeridas.items():
        try:
            version_actual = pkg_resources.get_distribution(paquete).version
            if pkg_resources.parse_version(version_actual) < pkg_resources.parse_version(version_min):
                desactualizadas.append(f"{paquete} (actual: {version_actual}, requerida: {version_min})")
        except pkg_resources.DistributionNotFound:
            faltantes.append(paquete)
    
    if faltantes or desactualizadas:
        print("🔥 Dependencias faltantes o desactualizadas encontradas:")
        if faltantes:
            print("\nFaltantes:")
            for paquete in faltantes:
                print(f"- {paquete}")
        if desactualizadas:
            print("\nDesactualizadas:")
            for paquete in desactualizadas:
                print(f"- {paquete}")
        print("\nPuede instalar/actualizar las dependencias usando:")
        print("pip install -r requirements.txt")
    else:
        print("✅ Todas las dependencias están instaladas y actualizadas!")

# Verificar dependencias
verificar_dependencias()
# Out:
# ✅ Todas las dependencias están instaladas y actualizadas!

# %% [markdown]
# ## 📜 Contexto Histórico
#
# El RMS Titanic fue un transatlántico británico que se hundió en las aguas del Atlántico Norte en la noche del 14 al 15 de abril de 1912, durante su viaje inaugural desde Southampton a Nueva York. De los 2,224 pasajeros y tripulantes a bordo, más de 1,500 perdieron la vida, lo que lo convierte en uno de los peores desastres marítimos en tiempos de paz.
#
# ### Datos Importantes:
# - **Fecha del hundimiento**: 15 de abril de 1912
# - **Ubicación**: Océano Atlántico Norte, 41°43′57″N 49°56′49″O
# - **Pasajeros totales**: 2,224
# - **Fallecidos**: ~1,500
# - **Sobrevivientes**: ~722
#
# ### Clases Sociales a Bordo:
# 1. **Primera Clase**: Caracterizada por lujo y comodidades excepcionales
# 2. **Segunda Clase**: Comparable a primera clase en otros barcos de la época
# 3. **Tercera Clase**: También conocida como clase turista
#
# ### Factores del Desastre:
# - Velocidad excesiva en zona de icebergs
# - Número insuficiente de botes salvavidas
# - Procedimientos de evacuación deficientes
# - Temperaturas extremadamente frías del agua
#
# Este análisis explorará los patrones de supervivencia entre diferentes grupos de pasajeros, ofreciendo una visión única de uno de los desastres marítimos más famosos de la historia.

# %% [markdown]
# ## 📊 Descripción del Dataset
#
# El dataset del Titanic contiene información sobre los pasajeros, incluyendo si sobrevivieron o no. A continuación se describen las variables disponibles:
#
# ### Variables del Dataset:
#
# - **survived**: Variable objetivo
#   - 0 = No sobrevivió
#   - 1 = Sobrevivió
#
# - **pclass**: Clase del pasajero
#   - 1 = Primera clase
#   - 2 = Segunda clase
#   - 3 = Tercera clase
#
# - **name**: Nombre completo del pasajero
#
# - **sex**: Género del pasajero
#   - male = Masculino
#   - female = Femenino
#
# - **age**: Edad en años
#   - Si es menor de 1 año, se expresa como fracción
#   - Si es desconocida, aparece como NaN
#
# - **sibsp**: Número de hermanos/cónyuges a bordo
#   - Incluye hermanos, hermanas, hermanastros y cónyuges
#
# - **parch**: Número de padres/hijos a bordo
#   - Incluye padres, hijos, padrastros e hijastros
#
# - **ticket**: Número de billete
#
# - **fare**: Tarifa pagada por el billete
#   - Incluye el precio del billete de acompañantes
#
# - **cabin**: Número de cabina
#   - Puede contener múltiples cabinas
#   - NaN si no está disponible
#
# - **embarked**: Puerto de embarque
#   - C = Cherbourg
#   - Q = Queenstown
#   - S = Southampton

# %%
# Importar librerías necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Markdown

# Configuración de visualizaciones
plt.style.use('seaborn-v0_8')
sns.set_palette('husl')
# %matplotlib inline

# Configurar opciones de pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Función para verificar dependencias
def verificar_dependencias():
    import pkg_resources
    import subprocess
    
    dependencias_requeridas = {
        'pandas': '1.3.0',
        'numpy': '1.20.0',
        'matplotlib': '3.4.0',
        'seaborn': '0.11.0',
        'scikit-learn': '0.24.0'
    }
    
    faltantes = []
    desactualizadas = []
    
    for paquete, version_min in dependencias_requeridas.items():
        try:
            version_actual = pkg_resources.get_distribution(paquete).version
            if pkg_resources.parse_version(version_actual) < pkg_resources.parse_version(version_min):
                desactualizadas.append(f"{paquete} (actual: {version_actual}, requerida: {version_min})")
        except pkg_resources.DistributionNotFound:
            faltantes.append(paquete)
    
    if faltantes or desactualizadas:
        print("🔥 Dependencias faltantes o desactualizadas encontradas:")
        if faltantes:
            print("\nFaltantes:")
            for paquete in faltantes:
                print(f"- {paquete}")
        if desactualizadas:
            print("\nDesactualizadas:")
            for paquete in desactualizadas:
                print(f"- {paquete}")
        print("\nPuede instalar/actualizar las dependencias usando:")
        print("pip install -r requirements.txt")
    else:
        print("✅ Todas las dependencias están instaladas y actualizadas!")

# Verificar dependencias
verificar_dependencias()
# Out:
# ✅ Todas las dependencias están instaladas y actualizadas!

# %% [markdown]
# ## 🔍 Análisis Exploratorio de Datos
#
# Vamos a explorar los datos para entender mejor los patrones de supervivencia en el Titanic. Analizaremos:
#
# 1. Distribución de supervivencia
# 2. Relación entre clase social y supervivencia
# 3. Influencia del género y la edad
# 4. Impacto de viajar en familia
# 5. Patrones por puerto de embarque

# %%
# Cargar los datos
train_data = pd.read_csv('datasets/train.csv')

# Mostrar información general del dataset
print("📈 Dimensiones del dataset:", train_data.shape)
print("\n📋 Primeras filas del dataset:")
display(train_data.head())

# Información sobre los tipos de datos y valores faltantes
print("\nℹ️ Información del dataset:")
train_data.info()
# Out:
# 📈 Dimensiones del dataset: (891, 12)
#
# 📋 Primeras filas del dataset:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# Crear figura para visualizaciones de supervivencia
plt.figure(figsize=(15, 5))

# Gráfico 1: Supervivencia general
plt.subplot(131)
sns.countplot(data=train_data, x='Survived')
plt.title('Distribución de Supervivencia')
plt.xlabel('Sobrevivió')
plt.ylabel('Número de Pasajeros')

# Gráfico 2: Supervivencia por clase
plt.subplot(132)
sns.barplot(data=train_data, x='Pclass', y='Survived')
plt.title('Tasa de Supervivencia por Clase')
plt.xlabel('Clase')
plt.ylabel('Tasa de Supervivencia')

# Gráfico 3: Supervivencia por género
plt.subplot(133)
sns.barplot(data=train_data, x='Sex', y='Survived')
plt.title('Tasa de Supervivencia por Género')
plt.xlabel('Género')
plt.ylabel('Tasa de Supervivencia')

plt.tight_layout()
plt.show()

# %%
# Análisis de edad
plt.figure(figsize=(15, 5))

# Distribución de edad
plt.subplot(131)
sns.histplot(data=train_data, x='Age', bins=30)
plt.title('Distribución de Edad')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')

# Supervivencia por grupos de edad
age_series = train_data['Age'].fillna(train_data['Age'].median())
age_bins = pd.qcut(age_series, q=5, duplicates='drop')
unique_bins = age_bins.unique()
labels = ['Muy joven', 'Joven', 'Adulto', 'Mayor', 'Anciano'][:len(unique_bins)]
train_data['AgeGroup'] = pd.qcut(age_series, q=len(unique_bins), labels=labels)

plt.subplot(132)
sns.barplot(data=train_data, x='AgeGroup', y='Survived')
plt.title('Supervivencia por Grupo de Edad')
plt.xticks(rotation=45)
plt.xlabel('Grupo de Edad')
plt.ylabel('Tasa de Supervivencia')

# Boxplot de edad por clase
plt.subplot(133)
sns.boxplot(data=train_data, x='Pclass', y='Age')
plt.title('Distribución de Edad por Clase')
plt.xlabel('Clase')
plt.ylabel('Edad')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 👪 Análisis de Relaciones Familiares
#
# Las variables `SibSp` (hermanos/cónyuges) y `Parch` (padres/hijos) nos permiten analizar cómo el viajar en familia afectó la supervivencia.

# %%
# Crear variable de tamaño familiar
train_data['FamilySize'] = train_data['SibSp'] + train_data['Parch'] + 1

# Visualizar supervivencia por tamaño familiar
plt.figure(figsize=(15, 5))

# Tamaño familiar
plt.subplot(131)
sns.countplot(data=train_data, x='FamilySize')
plt.title('Distribución de Tamaño Familiar')
plt.xlabel('Tamaño de la Familia')
plt.ylabel('Número de Pasajeros')

# Supervivencia por tamaño familiar
plt.subplot(132)
sns.barplot(data=train_data, x='FamilySize', y='Survived')
plt.title('Tasa de Supervivencia por Tamaño Familiar')
plt.xlabel('Tamaño de la Familia')
plt.ylabel('Tasa de Supervivencia')

# Tamaño familiar por clase
plt.subplot(133)
sns.boxplot(data=train_data, x='Pclass', y='FamilySize')
plt.title('Tamaño Familiar por Clase')
plt.xlabel('Clase')
plt.ylabel('Tamaño de la Familia')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 💲 Análisis de Tarifas
#
# Las tarifas pagadas por los pasajeros pueden darnos información valiosa sobre su estatus socioeconómico y su relación con la supervivencia.

# %%
plt.figure(figsize=(15, 5))

# Distribución de tarifas
plt.subplot(131)
sns.histplot(data=train_data, x='Fare', bins=50)
plt.title('Distribución de Tarifas')
plt.xlabel('Tarifa')
plt.ylabel('Frecuencia')

# Tarifas por clase
plt.subplot(132)
sns.boxplot(data=train_data, x='Pclass', y='Fare')
plt.title('Distribución de Tarifas por Clase')
plt.xlabel('Clase')
plt.ylabel('Tarifa')

# Relación entre tarifa y supervivencia
train_data['FareGroup'] = pd.qcut(train_data['Fare'], q=5, 
                                 labels=['Muy baja', 'Baja', 'Media', 'Alta', 'Muy alta'])
plt.subplot(133)
sns.barplot(data=train_data, x='FareGroup', y='Survived')
plt.title('Supervivencia por Grupo de Tarifa')
plt.xticks(rotation=45)
plt.xlabel('Grupo de Tarifa')
plt.ylabel('Tasa de Supervivencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🚢 Análisis de Puertos de Embarque
#
# El puerto de embarque puede indicar el origen geográfico de los pasajeros y posiblemente su estatus socioeconómico.

# %%
plt.figure(figsize=(15, 5))

# Distribución de puertos de embarque
plt.subplot(131)
sns.countplot(data=train_data, x='Embarked')
plt.title('Distribución de Puertos de Embarque')
plt.xlabel('Puerto')
plt.ylabel('Número de Pasajeros')

# Supervivencia por puerto
plt.subplot(132)
sns.barplot(data=train_data, x='Embarked', y='Survived')
plt.title('Tasa de Supervivencia por Puerto')
plt.xlabel('Puerto')
plt.ylabel('Tasa de Supervivencia')

# Clase por puerto
embarked_class = pd.crosstab(train_data['Embarked'], train_data['Pclass'])
plt.subplot(133)
embarked_class.plot(kind='bar', stacked=True)
plt.title('Distribución de Clases por Puerto')
plt.xlabel('Puerto')
plt.ylabel('Número de Pasajeros')
plt.legend(title='Clase')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📋 Conclusiones del Análisis
#
# Del análisis exploratorio de datos podemos extraer las siguientes conclusiones importantes:
#
# ### Factores que aumentaron las probabilidades de supervivencia:
#
# 1. **Género**:
#    - Las mujeres tuvieron una tasa de supervivencia significativamente mayor
#    - Esto refleja la política de "mujeres y niños primero" en la evacuación
#
# 2. **Clase Social**:
#    - Los pasajeros de primera clase tuvieron mayores probabilidades de sobrevivir
#    - La tasa de supervivencia disminuye significativamente en las clases inferiores
#    - Esto podría deberse a la ubicación de los camarotes y el acceso a los botes salvavidas
#
# 3. **Edad**:
#    - Los niños tuvieron mayores tasas de supervivencia
#    - Los adultos mayores tuvieron las tasas más bajas
#
# 4. **Tamaño Familiar**:
#    - Las personas que viajaban con familia tuvieron mejores probabilidades
#    - Sin embargo, las familias muy numerosas tuvieron menor tasa de supervivencia
#
# 5. **Puerto de Embarque**:
#    - Los pasajeros que embarcaron en Cherbourg tuvieron mejor tasa de supervivencia
#    - Esto podría estar relacionado con la clase social predominante en cada puerto
#
# ### Factores de Riesgo:
#
# 1. **Clase Baja**: Los pasajeros de tercera clase tuvieron las menores tasas de supervivencia
# 2. **Género Masculino**: Los hombres tuvieron una tasa de supervivencia significativamente menor
# 3. **Viajar Solo**: Los pasajeros solitarios tuvieron menor probabilidad de sobrevivir
# 4. **Tarifas Bajas**: Existe una correlación positiva entre el precio del billete y la supervivencia
#
# Estas conclusiones nos ayudan a entender los factores sociales y demográficos que influyeron en la tragedia del Titanic, reflejando las desigualdades sociales de la época.

# %% [markdown]
# # 🚢 Análisis de Supervivencia del Titanic
#
# Este notebook presenta un análisis completo del famoso dataset del Titanic, donde exploraremos los factores que influyeron en la supervivencia de los pasajeros usando técnicas de machine learning.
#
# ## 📋 Guía de Uso
#
# ### Requisitos Previos
# 1. **Python y Anaconda**: Asegúrate de tener instalado [Anaconda](https://www.anaconda.com/download)
# 2. **Ambiente Virtual**: Crea y activa un ambiente virtual con:
#    ```powershell
#    conda create -n titanic_env python=3.9
#    conda activate titanic_env
#    ```
# 3. **Dependencias**: Instala las librerías necesarias:
#    ```powershell
#    conda install numpy pandas matplotlib seaborn scikit-learn
#    conda install -c conda-forge xgboost lightgbm missingno
#    ```
#
# ### Estructura del Proyecto
# ```
# titanic/
# ├── datasets/               # Datos originales
# │   ├── train.csv          # Conjunto de entrenamiento
# │   ├── test.csv           # Conjunto de prueba
# │   └── gender_submission.csv  # Ejemplo de submission
# ├── src/                   # Módulos de código
# │   ├── data_loader.py     # Funciones de carga de datos
# │   ├── eda.py            # Análisis exploratorio
# │   ├── feature_engineering.py  # Ingeniería de características
# │   ├── preprocessor.py    # Preprocesamiento
# │   └── modeling.py        # Modelado y evaluación
# └── requirements.txt       # Lista de dependencias
# ```
#
# ## 📋 Contenido
# 1. [Configuración del Ambiente](#configuración-del-ambiente)
# 2. [Carga y Exploración de Datos](#carga-y-exploración-de-datos)
# 3. [Análisis Exploratorio Detallado](#análisis-exploratorio)
# 4. [Ingeniería de Características](#ingeniería-de-características)
# 5. [Preprocesamiento de Datos](#preprocesamiento)
# 6. [Modelado y Evaluación](#modelado-y-evaluación)
# 7. [Conclusiones](#conclusiones)
#
# ## 🎯 Objetivos del Análisis
# 1. Entender los factores que influyeron en la supervivencia
# 2. Crear visualizaciones informativas de los patrones en los datos
# 3. Desarrollar un modelo predictivo robusto
# 4. Analizar la importancia de diferentes características
# 5. Generar predicciones para el conjunto de prueba
#
# ## 🛠 Helpers y Utilidades
# A lo largo del notebook utilizaremos varias funciones auxiliares para:
# - Visualización de datos faltantes
# - Análisis de variables numéricas y categóricas
# - Creación de características derivadas
# - Evaluación de modelos
#
# Estas funciones están organizadas en módulos en la carpeta `src/` para mantener el código limpio y reutilizable.

# %% [markdown]
# ## Carga y Primera Exploración de Datos
#
# En esta sección, cargaremos los datasets y realizaremos una exploración inicial para entender la estructura y calidad de nuestros datos.
#
# ### Proceso de Exploración:
# 1. Carga de los tres conjuntos de datos
# 2. Visualización de las primeras filas
# 3. Análisis de tipos de datos
# 4. Identificación de valores faltantes
# 5. Estadísticas descriptivas básicas
#
# ### 🔍 Aspectos a Observar:
# - Dimensiones de los conjuntos de datos
# - Tipos de variables (numéricas/categóricas)
# - Presencia de valores faltantes
# - Rangos y distribuciones de valores

# %%
# Carga de datasets
train_data = pd.read_csv('datasets/train.csv')
test_data = pd.read_csv('datasets/test.csv')
gender_submission = pd.read_csv('datasets/gender_submission.csv')

# Información básica de los datasets
print("Forma del conjunto de entrenamiento:", train_data.shape)
print("Forma del conjunto de prueba:", test_data.shape)

# Mostrar las primeras filas y información del conjunto de entrenamiento
print("\nPrimeras filas del conjunto de entrenamiento:")
display(train_data.head())
print("\nInformación del conjunto de entrenamiento:")
print(train_data.info())
# Out:
# Forma del conjunto de entrenamiento: (891, 12)
# Forma del conjunto de prueba: (418, 11)
#
# Primeras filas del conjunto de entrenamiento:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# ...

# %% [markdown]
# ## 2. Análisis Exploratorio de Datos (EDA)
#
# Realizaremos un análisis exploratorio más profundo para entender mejor nuestros datos.

# %% [markdown]
# ## Contexto Histórico del RMS Titanic
#
# El RMS Titanic fue un transatlántico británico que se hundió en las primeras horas del 15 de abril de 1912, durante su viaje inaugural desde Southampton a Nueva York, tras chocar con un iceberg en el Océano Atlántico Norte.
#
# ### Datos Clave:
# - **Fecha del hundimiento**: 15 de abril de 1912
# - **Pasajeros totales**: 2,224 personas
# - **Supervivientes**: 706 personas
# - **Tasa de supervivencia**: ~32%
#
# ### Factores que Influyeron en la Supervivencia:
# 1. **Clase social**: Los pasajeros de primera clase tenían acceso prioritario a los botes salvavidas
# 2. **Género**: Se siguió la política "mujeres y niños primero"
# 3. **Ubicación de los camarotes**: La proximidad a la cubierta de botes salvavidas fue crucial
# 4. **Tamaño familiar**: Viajar en grupo podía ser tanto una ventaja como una desventaja
#
# Este contexto histórico es fundamental para entender los patrones en nuestros datos y las variables que analizaremos.
#
# ## 2. Análisis Exploratorio de Datos (EDA)
#
# Realizaremos un análisis exploratorio detallado para entender mejor nuestros datos y su relación con los eventos históricos.

# %%
# %pip install missingno --quiet
import missingno as msno

def plot_missing_values(df, title):
    """Visualiza los valores faltantes en el dataset"""
    plt.figure(figsize=(10, 6))
    msno.matrix(df)
    plt.title(f'Valores faltantes en {title}')
    plt.show()
    
    plt.figure(figsize=(10, 6))
    msno.bar(df)
    plt.title(f'Porcentaje de valores faltantes en {title}')
    plt.show()

# Visualizar valores faltantes
plot_missing_values(train_data, 'Conjunto de Entrenamiento')
plot_missing_values(test_data, 'Conjunto de Prueba')

# Estadísticas descriptivas
print("\nEstadísticas descriptivas del conjunto de entrenamiento:")
display(train_data.describe(include='all'))
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Estadísticas descriptivas del conjunto de entrenamiento:
#         PassengerId    Survived      Pclass                 Name   Sex  \
# count    891.000000  891.000000  891.000000                  891   891
# unique          NaN         NaN         NaN                  891     2
# top             NaN         NaN         NaN  Dooley, Mr. Patrick  male
# freq            NaN         NaN         NaN                    1   577
# mean     446.000000    0.383838    2.308642                  NaN   NaN
# std      257.353842    0.486592    0.836071                  NaN   NaN
# min        1.000000    0.000000    1.000000                  NaN   NaN
# 25%      223.500000    0.000000    2.000000                  NaN   NaN
# 50%      446.000000    0.000000    3.000000                  NaN   NaN
# 75%      668.500000    1.000000    3.000000                  NaN   NaN
# ...

# %% [markdown]
# ### 2.1 Análisis de Valores Faltantes
#
# La presencia de valores faltantes en el dataset del Titanic no es aleatoria y puede tener significado histórico:
#
# - **Age (Edad)**: Muchos pasajeros no declararon su edad o esta no fue registrada adecuadamente
# - **Cabin (Cabina)**: La mayoría de los registros de cabinas de tercera clase se perdieron
# - **Embarked (Puerto de embarque)**: Algunos registros de embarque están incompletos
#
# Analizaremos la distribución y patrones de estos valores faltantes:

# %% [markdown]
# ### 2.1 Análisis de Variables Numéricas

# %%
def plot_numerical_analysis(df):
    """Realiza análisis de variables numéricas"""
    numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
    
    # Distribuciones
    plt.figure(figsize=(15, 10))
    for i, col in enumerate(numerical_cols, 1):
        plt.subplot(3, 3, i)
        sns.histplot(data=df, x=col, kde=True)
        plt.title(f'Distribución de {col}')
    plt.tight_layout()
    plt.show()
    
    # Boxplots
    plt.figure(figsize=(15, 10))
    for i, col in enumerate(numerical_cols, 1):
        plt.subplot(3, 3, i)
        sns.boxplot(data=df, y=col)
        plt.title(f'Boxplot de {col}')
    plt.tight_layout()
    plt.show()
    
    # Matriz de correlación
    plt.figure(figsize=(10, 8))
    sns.heatmap(df[numerical_cols].corr(), annot=True, cmap='coolwarm', center=0)
    plt.title('Matriz de Correlación - Variables Numéricas')
    plt.show()

plot_numerical_analysis(train_data)

# %% [markdown]
# ### 2.2 Análisis de Variables Numéricas
#
# Analizaremos las variables numéricas para entender su distribución y relación con la supervivencia:
#
# - **Age**: Distribución de edades y su impacto en la supervivencia
# - **Fare**: Análisis de tarifas y su relación con la clase social
# - **SibSp y Parch**: Influencia del tamaño familiar
#
# #### 🔍 Aspectos a observar:
# 1. Distribuciones y valores atípicos
# 2. Correlaciones entre variables
# 3. Patrones por grupos de edad
# 4. Relación entre tarifa y supervivencia

# %%
def plot_categorical_analysis(df, target='Survived'):
    """Realiza análisis de variables categóricas"""
    categorical_cols = df.select_dtypes(include=['object']).columns
    
    # Distribución de variables categóricas
    plt.figure(figsize=(15, 5))
    for i, col in enumerate(categorical_cols, 1):
        plt.subplot(1, len(categorical_cols), i)
        sns.countplot(data=df, y=col)
        plt.title(f'Distribución de {col}')
    plt.tight_layout()
    plt.show()
    
    # Relación con la variable objetivo
    if target in df.columns:
        plt.figure(figsize=(15, 5))
        for i, col in enumerate(categorical_cols, 1):
            if col != target:
                plt.subplot(1, len(categorical_cols), i)
                sns.barplot(data=df, x=col, y=target)
                plt.title(f'{col} vs {target}')
        plt.tight_layout()
        plt.show()

plot_categorical_analysis(train_data)

# %% [markdown]
# ## 3. Feature Engineering
#
# Crearemos nuevas características y mejoraremos las existentes.
#
# ### 2.3 Análisis de Variables Categóricas
#
# Las variables categóricas contienen información crucial sobre las características sociales y logísticas del viaje:
#
# - **Pclass**: Refleja la estratificación social a bordo
# - **Sex**: Crucial debido a la política "mujeres y niños primero"
# - **Embarked**: Puede indicar la clase social y nacionalidad
# - **Cabin**: Primera letra indica la cubierta
#
# #### 🔍 Variables derivadas potenciales:
# 1. Títulos honoríficos de los nombres
# 2. Grupos familiares
# 3. Cubiertas de las cabinas
# 4. Categorías de tarifas

# %%
class TitanicFeatureEngineering:
    def __init__(self):
        self.title_mapping = {}
        self.fare_bins = None
        self.age_bins = None
    
    def extract_title(self, name):
        """Extrae el título del nombre"""
        title = name.split(',')[1].split('.')[0].strip()
        if title in ['Mr', 'Mrs', 'Miss', 'Master']:
            return title
        return 'Other'
    
    def create_family_size(self, df):
        """Crea características relacionadas con el tamaño de la familia"""
        df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
        df['IsAlone'] = (df['FamilySize'] == 1).astype(int)
        return df
    
    def create_age_bins(self, df):
        """Crea bins de edad"""
        df['AgeBin'] = pd.qcut(df['Age'], q=4, labels=['Young', 'Adult', 'MiddleAge', 'Senior'])
        return df
    
    def create_fare_bins(self, df):
        """Crea bins de tarifa"""
        df['FareBin'] = pd.qcut(df['Fare'], q=4, labels=['Low', 'Medium', 'High', 'VeryHigh'])
        return df
    
    def extract_cabin_info(self, df):
        """Extrae información de la cabina"""
        df['CabinDeck'] = df['Cabin'].str[0]
        df['CabinDeck'] = df['CabinDeck'].fillna('U')
        return df
    
    def transform(self, df):
        """Aplica todas las transformaciones de feature engineering"""
        # Copia del dataframe
        df = df.copy()
        
        # Extracción de título
        df['Title'] = df['Name'].apply(self.extract_title)
        
        # Características de familia
        df = self.create_family_size(df)
        
        # Bins de edad y tarifa
        df = self.create_age_bins(df)
        df = self.create_fare_bins(df)
        
        # Información de cabina
        df = self.extract_cabin_info(df)
        
        return df

# Aplicar feature engineering
fe = TitanicFeatureEngineering()
train_data_fe = fe.transform(train_data)
test_data_fe = fe.transform(test_data)

# Mostrar las nuevas características
print("Nuevas características creadas:")
display(train_data_fe.head())
# Out:
# Nuevas características creadas:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title  FamilySize  IsAlone  \
# 0      0         A/5 21171   7.2500   NaN        S    Mr           2        0
# 1      0          PC 17599  71.2833   C85        C   Mrs           2        0
# ...

# %% [markdown]
# ## 4. Preprocesamiento de Datos
#
# Crearemos un pipeline de preprocesamiento robusto.

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

class TitanicPreprocessor:
    def __init__(self):
        self.numerical_features = ['Age', 'Fare', 'FamilySize']
        self.categorical_features = ['Sex', 'Embarked', 'Title', 'CabinDeck', 'AgeBin', 'FareBin']
        
    def create_pipeline(self):
        # Pipeline para variables numéricas
        numerical_pipeline = Pipeline([
            ('imputer', KNNImputer(n_neighbors=5)),
            ('scaler', StandardScaler())
        ])
        
        # Pipeline para variables categóricas
        categorical_pipeline = Pipeline([
            ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
            ('onehot', OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'))
        ])
        
        # Combinación de pipelines
        preprocessor = ColumnTransformer(
            transformers=[
                ('num', numerical_pipeline, self.numerical_features),
                ('cat', categorical_pipeline, self.categorical_features)
            ])
        
        return preprocessor

# Crear y ajustar el preprocesador
preprocessor = TitanicPreprocessor().create_pipeline()

# Separar features y target
X_train = train_data_fe.drop(['Survived', 'PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1)
y_train = train_data_fe['Survived']
X_test = test_data_fe.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1)

# Ajustar el preprocesador
X_train_processed = preprocessor.fit_transform(X_train)
X_test_processed = preprocessor.transform(X_test)

# Verificar la forma de los datos procesados
print("Forma de los datos de entrenamiento procesados:", X_train_processed.shape)
print("Forma de los datos de prueba procesados:", X_test_processed.shape)
# Out:
# Forma de los datos de entrenamiento procesados: (891, 26)
# Forma de los datos de prueba procesados: (418, 26)
# c:\Users\dmard\anaconda3\envs\titanic_env\lib\site-packages\sklearn\preprocessing\_encoders.py:246: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ## 5. Modelado y Evaluación
#
# Implementaremos múltiples modelos con validación cruzada y optimización de hiperparámetros.

# %%
# %pip install xgboost lightgbm --quiet

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from xgboost import XGBClassifier
import lightgbm as lgb

RANDOM_STATE = 158

class TitanicModeling:
    def __init__(self):
        self.models = {
            'logistic': LogisticRegression(random_state=RANDOM_STATE),
            'random_forest': RandomForestClassifier(random_state=RANDOM_STATE),
            'xgboost': XGBClassifier(random_state=RANDOM_STATE),
            'lightgbm': lgb.LGBMClassifier(random_state=RANDOM_STATE)
        }
        
        self.param_grids = {
            'logistic': {
                'C': [0.001, 0.01, 0.1, 1, 10],
                'penalty': ['l1', 'l2'],
                'solver': ['liblinear']
            },
            'random_forest': {
                'n_estimators': [100, 200],
                'max_depth': [None, 10, 20],
                'min_samples_split': [2, 5],
                'min_samples_leaf': [1, 2]
            },
            'xgboost': {
                'n_estimators': [100, 200],
                'max_depth': [3, 5, 7],
                'learning_rate': [0.01, 0.1]
            },
            'lightgbm': {
                'n_estimators': [100, 200],
                'max_depth': [3, 5, 7],
                'learning_rate': [0.01, 0.1]
            }
        }
    
    def train_and_evaluate(self, X, y, cv=5):
        """Entrena y evalúa múltiples modelos usando validación cruzada"""
        results = {}
        
        for name, model in self.models.items():
            # Búsqueda de hiperparámetros
            grid_search = GridSearchCV(
                model,
                self.param_grids[name],
                cv=StratifiedKFold(n_splits=cv, shuffle=True, random_state=RANDOM_STATE),
                scoring='accuracy',
                n_jobs=-1
            )
            
            # Ajustar el modelo
            grid_search.fit(X, y)
            
            # Guardar resultados
            results[name] = {
                'best_score': grid_search.best_score_,
                'best_params': grid_search.best_params_,
                'model': grid_search.best_estimator_
            }
            
            print(f"\nResultados para {name}:")
            print(f"Mejor puntuación: {grid_search.best_score_:.4f}")
            print(f"Mejores parámetros: {grid_search.best_params_}")
        
        return results

# Entrenar y evaluar modelos
modeling = TitanicModeling()
results = modeling.train_and_evaluate(X_train_processed, y_train)
# Out:
# Note: you may need to restart the kernel to use updated packages.
#
# Resultados para logistic:
# Mejor puntuación: 0.8250
# Mejores parámetros: {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}
#
# Resultados para logistic:
# Mejor puntuación: 0.8250
# Mejores parámetros: {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}
#
# Resultados para random_forest:
# Mejor puntuación: 0.8283
# Mejores parámetros: {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
#
# Resultados para random_forest:
# Mejor puntuación: 0.8283
# Mejores parámetros: {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
#
# Resultados para xgboost:
# Mejor puntuación: 0.8238
# Mejores parámetros: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
#
# Resultados para xgboost:
# Mejor puntuación: 0.8238
# Mejores parámetros: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
# Exception in thread Thread-31:
# ...

# %% [markdown]
# ## 6. Análisis de Resultados y Visualizaciones

# %%
def plot_model_comparison(results):
    """Visualiza la comparación de modelos"""
    models = list(results.keys())
    scores = [results[model]['best_score'] for model in models]
    
    plt.figure(figsize=(10, 6))
    sns.barplot(x=models, y=scores)
    plt.title('Comparación de Modelos - Accuracy en Validación Cruzada')
    plt.ylim(0.7, 1.0)
    plt.xticks(rotation=45)
    plt.show()

# Comparar modelos
plot_model_comparison(results)

# Seleccionar el mejor modelo
best_model_name = max(results.keys(), key=lambda k: results[k]['best_score'])
best_model = results[best_model_name]['model']
print(f"\nMejor modelo: {best_model_name}")
print(f"Accuracy en validación cruzada: {results[best_model_name]['best_score']:.4f}")
# Out:
# Mejor modelo: random_forest
# Accuracy en validación cruzada: 0.8283

# %% [markdown]
# ## 7. Predicciones Finales
#
# Realizaremos las predicciones finales con el mejor modelo.

# %%
# Realizar predicciones
final_predictions = best_model.predict(X_test_processed)

# Crear DataFrame de submission
submission = pd.DataFrame({
    'PassengerId': test_data['PassengerId'],
    'Survived': final_predictions
})

# Guardar predicciones
submission.to_csv('predictions_improved.csv', index=False)
print("\nPredicciones guardadas en 'predictions_improved.csv'")

# Mostrar las primeras predicciones
print("\nPrimeras predicciones:")
display(submission.head())
# Out:
# Predicciones guardadas en 'predictions_improved.csv'
#
# Primeras predicciones:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %% [markdown]
# ## 8. Conclusiones
#
# 1. El mejor modelo obtenido fue el {best_model_name} con una precisión de {results[best_model_name]['best_score']:.4f}
# 2. Las características más importantes para la predicción fueron el sexo, la clase del pasajero y la edad
# 3. El feature engineering y la optimización de hiperparámetros mejoraron significativamente el rendimiento del modelo
# 4. La validación cruzada nos da confianza en la generalización del modelo
#
# ### Mejoras Implementadas:
# - Feature Engineering más sofisticado
# - Manejo avanzado de valores faltantes con KNNImputer
# - Pipeline robusto de preprocesamiento
# - Optimización de hiperparámetros con GridSearchCV
# - Validación cruzada estratificada
# - Comparación de múltiples modelos
# - Visualizaciones más informativas

# %% [markdown]
# ## Configuración del Ambiente
#
# En esta sección verificaremos que todas las dependencias necesarias estén instaladas y configuraremos el ambiente de trabajo.</VSCode.Cell>
#
# <VSCode.Cell language="python">
# # Verificación de dependencias necesarias
# import sys
# import subprocess
# from IPython.display import display, Markdown
#
# def check_dependency(package_name):
#     """Verifica si una dependencia está instalada y muestra su versión"""
#     try:
#         module = __import__(package_name)
#         print(f"✅ {package_name}: {module.__version__}")
#         return True
#     except ImportError:
#         print(f"❌ {package_name} no está instalado")
#         return False
#
# # Lista de dependencias principales
# dependencies = [
#     'numpy',
#     'pandas',
#     'matplotlib',
#     'seaborn',
#     'scikit-learn',
#     'xgboost',
#     'lightgbm',
#     'missingno'
# ]
#
# print("Verificando dependencias:")
# for dep in dependencies:
#     check_dependency(dep)
#
# # Configuraciones globales
# import warnings
# warnings.filterwarnings('ignore')  # Suprimir warnings para una salida más limpia
#
# # Configuración de visualización
# import matplotlib.pyplot as plt
# import seaborn as sns
# plt.style.use('seaborn')
# sns.set_palette("husl")
# plt.rcParams['figure.figsize'] = [10, 6]
# plt.rcParams['figure.dpi'] = 100
#
# print("\nConfiguración completada ✨")

# %% [markdown]
# ## Descripción del Dataset
#
# El dataset del Titanic contiene información sobre los pasajeros que viajaban a bordo del RMS Titanic, que se hundió en su viaje inaugural en 1912. El objetivo es predecir qué pasajeros sobrevivieron al naufragio.
#
# ### Variables Disponibles
#
# #### Características Principales:
# - **PassengerId**: Identificador único para cada pasajero
# - **Survived**: Variable objetivo (1 = Sobrevivió, 0 = No sobrevivió)
# - **Pclass**: Clase del pasajero (1 = Primera, 2 = Segunda, 3 = Tercera)
# - **Name**: Nombre del pasajero
# - **Sex**: Género del pasajero
# - **Age**: Edad en años
# - **SibSp**: Número de hermanos/cónyuges a bordo
# - **Parch**: Número de padres/hijos a bordo
# - **Ticket**: Número de ticket
# - **Fare**: Tarifa pagada
# - **Cabin**: Número de cabina
# - **Embarked**: Puerto de embarque (C = Cherbourg, Q = Queenstown, S = Southampton)
#
# ### Conjuntos de Datos:
# 1. **train.csv**: Conjunto de entrenamiento (891 pasajeros)
# 2. **test.csv**: Conjunto de prueba (418 pasajeros)
# 3. **gender_submission.csv**: Ejemplo de formato de submission
#
# ### Objetivos del Análisis:
# 1. Explorar las relaciones entre variables
# 2. Identificar patrones de supervivencia
# 3. Crear características informativas
# 4. Desarrollar un modelo predictivo robusto</VSCode.Cell>
#
# <VSCode.Cell language="markdown">
# ## Importación de Librerías
#
# Comenzamos importando todas las librerías necesarias para nuestro análisis. Cada librería tiene un propósito específico:
#
# ### Análisis y Manipulación de Datos
# - `numpy`: Operaciones numéricas y arrays
# - `pandas`: Manipulación y análisis de datos tabulares
#
# ### Visualización
# - `matplotlib`: Biblioteca base para visualizaciones
# - `seaborn`: Visualizaciones estadísticas de alto nivel
# - `missingno`: Análisis de datos faltantes
#
# ### Machine Learning
# - `scikit-learn`: Herramientas de machine learning
# - `xgboost`: Implementación de Gradient Boosting

# %% [markdown]
# ## 📊 Carga y Exploración Inicial de Datos
#
# En esta sección, cargaremos el dataset del Titanic y realizaremos una exploración inicial para entender su estructura y contenido.

# %%
# Cargar los datos
df = cargar_datos()

# Mostrar información básica del dataset
print("\n📋 Información del Dataset:\n")
print(f"Dimensiones del dataset: {df.shape[0]} filas x {df.shape[1]} columnas\n")
df.info()

print("\n🔍 Primeras filas del dataset:\n")
df.head()

# %%
# Análisis estadístico descriptivo
print("\n📈 Estadísticas descriptivas:\n")
df.describe(include='all')

# Verificar valores nulos
print("\n❓ Análisis de valores faltantes:\n")
valores_nulos = df.isnull().sum()
porcentaje_nulos = (valores_nulos / len(df)) * 100

resumen_nulos = pd.DataFrame({
    'Valores Nulos': valores_nulos,
    'Porcentaje (%)': porcentaje_nulos
})

print(resumen_nulos[resumen_nulos['Valores Nulos'] > 0])

# %% [markdown]
# ## 📈 Análisis Exploratorio Visual
#
# En esta sección, exploraremos visualmente diferentes aspectos de los datos para identificar patrones y relaciones importantes.

# %%
# Visualizar la distribución general de supervivencia
plot_supervivencia_general(df)

# Analizar la supervivencia por clase
plot_supervivencia_por_clase(df)

# %%
# Analizar la distribución de edad y género
plot_piramide_edad_genero(df)

# Analizar el impacto del tamaño familiar
plot_familias(df)

# %%
# Analizar la relación entre tarifas y supervivencia
plot_tarifas_supervivencia(df)

# %% [markdown]
# ## 📑 Conclusiones
#
# Del análisis realizado, podemos extraer las siguientes conclusiones principales:
#
# ### Factores de Supervivencia
#
# 1. **Género**: Las mujeres tuvieron una tasa de supervivencia significativamente mayor que los hombres.
# 2. **Clase**: Los pasajeros de primera clase tuvieron mejores probabilidades de supervivencia.
# 3. **Edad**: Los niños (especialmente de primera y segunda clase) tuvieron mayores tasas de supervivencia.
#
# ### Patrones Demográficos
#
# 1. La mayoría de los pasajeros eran hombres jóvenes y adultos.
# 2. Había una proporción significativa de familias viajando juntas.
# 3. Las tarifas pagadas variaban considerablemente según la clase.
#
# ### Observaciones Adicionales
#
# 1. Existían datos faltantes importantes en campos como 'Age' y 'Cabin'.
# 2. La tarifa del pasaje mostró una correlación positiva con la supervivencia.
# 3. El puerto de embarque también influyó en las probabilidades de supervivencia.
#
# ### Implicaciones
#
# Estos hallazgos sugieren que la supervivencia en el desastre del Titanic estuvo fuertemente influenciada por factores socioeconómicos (clase) y demográficos (género y edad), reflejando las normas sociales y prácticas de la época.

# %%
# Cargar y preparar datos
df = cargar_datos()

# Información básica del dataset
print("📊 Dimensiones del dataset:", df.shape)
print("\n📋 Primeras filas del dataset:")
df.head()

# Información detallada
print("\nℹ️ Información del dataset:")
df.info()

# %%
# Análisis de valores faltantes
print("\n❓ Análisis de valores faltantes:")
valores_nulos = df.isnull().sum()
porcentaje_nulos = (valores_nulos / len(df)) * 100

resumen_nulos = pd.DataFrame({
    'Valores Nulos': valores_nulos,
    'Porcentaje (%)': porcentaje_nulos
})

print(resumen_nulos[resumen_nulos['Valores Nulos'] > 0])

# %% [markdown]
# ## 📊 Visualizaciones
#
# Analizaremos diferentes aspectos de los datos mediante visualizaciones:

# %%
# Visualizaciones de supervivencia
plot_supervivencia_general(df)
plot_supervivencia_por_clase(df)

# Visualizaciones demográficas
plot_piramide_edad_genero(df)
plot_familias(df)

# Visualización de tarifas
plot_tarifas_supervivencia(df)

# %% [markdown]
# ## 📝 Conclusiones
#
# Del análisis realizado podemos concluir:
#
# 1. **Supervivencia General**: La tasa de supervivencia general fue del 38.4%
# 2. **Factores Clave**:
#    - Las mujeres tuvieron mayor probabilidad de supervivencia
#    - Los pasajeros de primera clase tuvieron mejores tasas de supervivencia
#    - Los niños tuvieron mayores probabilidades de sobrevivir
# 3. **Datos Faltantes**: La variable 'Cabin' tiene un alto porcentaje de valores faltantes (77.1%)
# 4. **Relaciones Importantes**:
#    - Existe una correlación positiva entre el precio del pasaje y la supervivencia
#    - El tamaño familiar tuvo un impacto en la supervivencia

# %%
# 🛠️ Preparación del entorno
import sys
from pathlib import Path

# Configurar path
src_path = Path.cwd() / 'src'
if str(src_path) not in sys.path:
    sys.path.append(str(src_path))

# Importar nuestras herramientas
from utils import configurar_visualizacion
from data_loader import cargar_datos
from eda import (
    plot_supervivencia_general,
    plot_supervivencia_por_clase,
    plot_piramide_edad_genero,
    plot_familias,
    plot_tarifas_supervivencia
)

# Configurar visualizaciones
configurar_visualizacion()

# Cargar datos
df = cargar_datos()

# %%
# 👀 Vistazo rápido a los datos
print(f"📊 Pasajeros a bordo: {len(df)}")
print(f"💫 Características registradas: {df.shape[1]}\n")

print("🎫 Primeros pasajeros registrados:")
df.head(3)

# %% [markdown]
# ## 🔍 ¿Quién Sobrevivió al Desastre?
#
# Veamos los patrones de supervivencia entre diferentes grupos de pasajeros.

# %%
# 📊 Patrones de supervivencia
plot_supervivencia_general(df)
plot_supervivencia_por_clase(df)

# 👥 Análisis demográfico
plot_piramide_edad_genero(df)

# 👨‍👩‍👦 Análisis familiar
plot_familias(df)

# 💰 Análisis de tarifas
plot_tarifas_supervivencia(df)

# %% [markdown]
# ## 📝 Lo Que Nos Revelan los Datos
#
# ### 🎭 El Drama de las Clases Sociales
# - Los pasajeros de primera clase tuvieron una ventaja significativa en la supervivencia
# - La tarifa promedio en primera clase era 10 veces mayor que en tercera
#
# ### 👥 El Factor Humano
# - Las mujeres y los niños tuvieron prioridad en los botes salvavidas
# - Las familias pequeñas (2-4 miembros) tuvieron mejores tasas de supervivencia
#
# ### 💡 Lecciones Aprendidas
# - La clase social fue un factor determinante en la supervivencia
# - Las normas sociales de la época ("mujeres y niños primero") se reflejan en los datos
# - El desastre afectó de manera desproporcionada a los pasajeros de tercera clase
#
# > *"Los datos nos ayudan a contar la historia de una de las mayores tragedias marítimas, recordándonos la importancia de la seguridad y la igualdad en el mar."*
